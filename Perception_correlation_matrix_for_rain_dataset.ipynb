# %% [markdown]
# <a href="https://colab.research.google.com/github/ruwanwija/Research-Models/blob/main/Perception_correlation_matrix_for_rain_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Rathnapura_Dataset.csv')
df.head()
# Out:
#          time  weathercode  temperature_2m_max  temperature_2m_min  \
# 0  2015-01-01           51                28.1                21.3
# 1  2015-01-02            2                28.1                20.9
# 2  2015-01-03            3                29.5                20.2
# 3  2015-01-04           51                29.0                23.1
# 4  2015-01-05           51                28.9                22.2
#
#    temperature_2m_mean  apparent_temperature_max  apparent_temperature_min  \
# 0                 24.4                      35.1                      25.5
# 1                 24.4                      33.3                      24.2
# 2                 25.6                      36.4                      23.1
# 3                 25.6                      35.1                      28.0
# 4                 25.4                      34.8                      26.9
#
#    apparent_temperature_mean           sunrise            sunset  ...  \
# 0                       29.5  2015-01-01T00:49  2015-01-01T12:33  ...
# 1                       28.4  2015-01-02T00:49  2015-01-02T12:34  ...
# 2                       30.6  2015-01-03T00:50  2015-01-03T12:34  ...
# 3                       30.7  2015-01-04T00:50  2015-01-04T12:35  ...
# 4                       30.4  2015-01-05T00:51  2015-01-05T12:35  ...
#
#    Unnamed: 11  rain_sum  precipitation_hours  windspeed_10m_max  \
# 0          NaN       0.4                    3                9.1
# 1          NaN       0.0                    0               11.0
# 2          NaN       0.0                    0                9.0
# 3          NaN       0.7                    5                7.6
# 4          NaN       1.0                    8                7.2
#
#    windgusts_10m_max  winddirection_10m_dominant  et0_fao_evapotranspiration  \
# 0               24.1                         270                        3.64
# 1               25.6                         324                        3.99
# 2               18.4                         250                        4.53
# 3               18.4                         239                        3.41
# 4               16.6                         229                        3.75
#
#    latitude  longitude  elevation
# 0  6.800003   80.30002         27
# 1  6.800003   80.30002         27
# 2  6.800003   80.30002         27
# 3  6.800003   80.30002         27
# 4  6.800003   80.30002         27
#
# [5 rows x 21 columns]

# %%
df = df.drop('time', axis=1)

# %%
corr_matrix = df.corr(numeric_only=True)

# %%
print(corr_matrix)
# Out:
#                             weathercode  temperature_2m_max  \
# weathercode                    1.000000           -0.366082
# temperature_2m_max            -0.366082            1.000000
# temperature_2m_min             0.527044           -0.102337
# temperature_2m_mean           -0.138809            0.821611
# apparent_temperature_max      -0.121597            0.886593
# apparent_temperature_min       0.541319           -0.056909
# apparent_temperature_mean      0.102327            0.712273
# shortwave_radiation_sum       -0.447376            0.728958
# Unnamed: 11                         NaN                 NaN
# rain_sum                       0.397994           -0.329944
# precipitation_hours            0.587035           -0.631417
# windspeed_10m_max              0.124550           -0.451607
# windgusts_10m_max              0.234394           -0.473917
# winddirection_10m_dominant     0.013208           -0.242153
# et0_fao_evapotranspiration    -0.488433            0.819333
# latitude                            NaN                 NaN
# longitude                           NaN                 NaN
# elevation                           NaN                 NaN
#
#                             temperature_2m_min  temperature_2m_mean  \
# weathercode                           0.527044            -0.138809
# temperature_2m_max                   -0.102337             0.821611
# temperature_2m_min                    1.000000             0.371911
# temperature_2m_mean                   0.371911             1.000000
# apparent_temperature_max              0.027897             0.756267
# apparent_temperature_min              0.974103             0.395748
# apparent_temperature_mean             0.482418             0.908970
# shortwave_radiation_sum              -0.311227             0.537180
# Unnamed: 11                                NaN                  NaN
# rain_sum                              0.254231            -0.259004
# precipitation_hours                   0.532929            -0.357169
# windspeed_10m_max                     0.332667            -0.206569
# windgusts_10m_max                     0.391052            -0.226559
# winddirection_10m_dominant            0.189533            -0.086422
# et0_fao_evapotranspiration           -0.338574             0.604675
# latitude                                   NaN                  NaN
# longitude                                  NaN                  NaN
# elevation                                  NaN                  NaN
#
#                             apparent_temperature_max  \
# weathercode                                -0.121597
# temperature_2m_max                          0.886593
# temperature_2m_min                          0.027897
# temperature_2m_mean                         0.756267
# apparent_temperature_max                    1.000000
# apparent_temperature_min                    0.102239
# apparent_temperature_mean                   0.818470
# shortwave_radiation_sum                     0.586956
# Unnamed: 11                                      NaN
# rain_sum                                   -0.160489
# precipitation_hours                        -0.482850
# windspeed_10m_max                          -0.605827
# windgusts_10m_max                          -0.565602
# winddirection_10m_dominant                 -0.325928
# et0_fao_evapotranspiration                  0.672379
# latitude                                         NaN
# longitude                                        NaN
# elevation                                        NaN
#
#                             apparent_temperature_min  \
# weathercode                                 0.541319
# temperature_2m_max                         -0.056909
# temperature_2m_min                          0.974103
# temperature_2m_mean                         0.395748
# apparent_temperature_max                    0.102239
# apparent_temperature_min                    1.000000
# apparent_temperature_mean                   0.553249
# shortwave_radiation_sum                    -0.283044
# Unnamed: 11                                      NaN
# rain_sum                                    0.239997
# precipitation_hours                         0.505743
# windspeed_10m_max                           0.232069
# windgusts_10m_max                           0.286353
# winddirection_10m_dominant                  0.155201
# et0_fao_evapotranspiration                 -0.303397
# latitude                                         NaN
# longitude                                        NaN
# elevation                                        NaN
#
#                             apparent_temperature_mean  \
# weathercode                                  0.102327
# temperature_2m_max                           0.712273
# temperature_2m_min                           0.482418
# temperature_2m_mean                          0.908970
# apparent_temperature_max                     0.818470
# apparent_temperature_min                     0.553249
# apparent_temperature_mean                    1.000000
# shortwave_radiation_sum                      0.353776
# Unnamed: 11                                       NaN
# rain_sum                                    -0.092434
# precipitation_hours                         -0.209434
# windspeed_10m_max                           -0.376285
# windgusts_10m_max                           -0.344517
# winddirection_10m_dominant                  -0.167939
# et0_fao_evapotranspiration                   0.425277
# latitude                                          NaN
# longitude                                         NaN
# elevation                                         NaN
#
#                             shortwave_radiation_sum  Unnamed: 11  rain_sum  \
# weathercode                               -0.447376          NaN  0.397994
# temperature_2m_max                         0.728958          NaN -0.329944
# temperature_2m_min                        -0.311227          NaN  0.254231
# temperature_2m_mean                        0.537180          NaN -0.259004
# apparent_temperature_max                   0.586956          NaN -0.160489
# apparent_temperature_min                  -0.283044          NaN  0.239997
# apparent_temperature_mean                  0.353776          NaN -0.092434
# shortwave_radiation_sum                    1.000000          NaN -0.520088
# Unnamed: 11                                     NaN          NaN       NaN
# rain_sum                                  -0.520088          NaN  1.000000
# precipitation_hours                       -0.601046          NaN  0.521428
# windspeed_10m_max                         -0.129454          NaN  0.044140
# windgusts_10m_max                         -0.198161          NaN  0.106017
# winddirection_10m_dominant                -0.054273          NaN -0.009260
# et0_fao_evapotranspiration                 0.980645          NaN -0.509639
# latitude                                        NaN          NaN       NaN
# longitude                                       NaN          NaN       NaN
# elevation                                       NaN          NaN       NaN
#
#                             precipitation_hours  windspeed_10m_max  \
# weathercode                            0.587035           0.124550
# temperature_2m_max                    -0.631417          -0.451607
# temperature_2m_min                     0.532929           0.332667
# temperature_2m_mean                   -0.357169          -0.206569
# apparent_temperature_max              -0.482850          -0.605827
# apparent_temperature_min               0.505743           0.232069
# apparent_temperature_mean             -0.209434          -0.376285
# shortwave_radiation_sum               -0.601046          -0.129454
# Unnamed: 11                                 NaN                NaN
# rain_sum                               0.521428           0.044140
# precipitation_hours                    1.000000           0.471278
# windspeed_10m_max                      0.471278           1.000000
# windgusts_10m_max                      0.530056           0.907535
# winddirection_10m_dominant             0.196323           0.514957
# et0_fao_evapotranspiration            -0.682973          -0.260763
# latitude                                    NaN                NaN
# longitude                                   NaN                NaN
# elevation                                   NaN                NaN
#
#                             windgusts_10m_max  winddirection_10m_dominant  \
# weathercode                          0.234394                    0.013208
# temperature_2m_max                  -0.473917                   -0.242153
# temperature_2m_min                   0.391052                    0.189533
# temperature_2m_mean                 -0.226559                   -0.086422
# apparent_temperature_max            -0.565602                   -0.325928
# apparent_temperature_min             0.286353                    0.155201
# apparent_temperature_mean           -0.344517                   -0.167939
# shortwave_radiation_sum             -0.198161                   -0.054273
# Unnamed: 11                               NaN                         NaN
# rain_sum                             0.106017                   -0.009260
# precipitation_hours                  0.530056                    0.196323
# windspeed_10m_max                    0.907535                    0.514957
# windgusts_10m_max                    1.000000                    0.421889
# winddirection_10m_dominant           0.421889                    1.000000
# et0_fao_evapotranspiration          -0.331189                   -0.120501
# latitude                                  NaN                         NaN
# longitude                                 NaN                         NaN
# elevation                                 NaN                         NaN
#
#                             et0_fao_evapotranspiration  latitude  longitude  \
# weathercode                                  -0.488433       NaN        NaN
# temperature_2m_max                            0.819333       NaN        NaN
# temperature_2m_min                           -0.338574       NaN        NaN
# temperature_2m_mean                           0.604675       NaN        NaN
# apparent_temperature_max                      0.672379       NaN        NaN
# apparent_temperature_min                     -0.303397       NaN        NaN
# apparent_temperature_mean                     0.425277       NaN        NaN
# shortwave_radiation_sum                       0.980645       NaN        NaN
# Unnamed: 11                                        NaN       NaN        NaN
# rain_sum                                     -0.509639       NaN        NaN
# precipitation_hours                          -0.682973       NaN        NaN
# windspeed_10m_max                            -0.260763       NaN        NaN
# windgusts_10m_max                            -0.331189       NaN        NaN
# winddirection_10m_dominant                   -0.120501       NaN        NaN
# et0_fao_evapotranspiration                    1.000000       NaN        NaN
# latitude                                           NaN       NaN        NaN
# longitude                                          NaN       NaN        NaN
# elevation                                          NaN       NaN        NaN
#
#                             elevation
# weathercode                       NaN
# temperature_2m_max                NaN
# temperature_2m_min                NaN
# temperature_2m_mean               NaN
# apparent_temperature_max          NaN
# apparent_temperature_min          NaN
# apparent_temperature_mean         NaN
# shortwave_radiation_sum           NaN
# Unnamed: 11                       NaN
# rain_sum                          NaN
# precipitation_hours               NaN
# windspeed_10m_max                 NaN
# windgusts_10m_max                 NaN
# winddirection_10m_dominant        NaN
# et0_fao_evapotranspiration        NaN
# latitude                          NaN
# longitude                         NaN
# elevation                         NaN

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
